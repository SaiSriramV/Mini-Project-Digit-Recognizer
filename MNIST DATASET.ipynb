# %%
import tensorflow as tf

# %%
digits=tf.keras.datasets.mnist
(x_train,y_train),(x_test,y_test) = digits.load_data()

# %%
import matplotlib.pyplot as plt
plt.imshow(x_train[1900],cmap='gray')
plt.show()

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(512,activation ='relu'))
model.add(tf.keras.layers.Dense(10,activation='softmax'))

# %%
model.compile(optimizer='adam',loss = 'sparse_categorical_crossentropy',metrics = 'accuracy')

# %%
history = model.fit(x_train,y_train,epochs = 5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 2.8481 - accuracy: 0.9074
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3467 - accuracy: 0.9391
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3017 - accuracy: 0.9413
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2747 - accuracy: 0.9455
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2597 - accuracy: 0.9499

# %%
y_pred = model.predict_classes(x_test)
y_pred
# Out:
# array([7, 2, 1, ..., 4, 5, 6])

# %%
#Evaluation
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.9412

# %%
confusion_matrix(y_pred,y_test)
# Out:
# array([[ 934,    0,    7,    2,    1,    4,    5,    0,    5,    1],
#        [   0, 1097,   22,    4,    0,    1,    2,    4,    0,    4],
#        [  17,    9,  972,   13,    2,    0,    2,   21,    7,    3],
#        [   2,    4,    4,  965,    1,   41,    1,   34,   17,   21],
#        [   8,    1,    5,    0,  935,    1,    5,   12,    8,   25],
#        [   2,    1,    0,    7,    0,  812,    3,    1,    2,    0],
#        [   6,    2,    3,    0,    7,    8,  931,    0,    4,    0],
#        [   1,    1,    4,    1,    0,    0,    0,  901,    1,    0],
#        [   8,   14,   15,   16,    5,   18,    9,    4,  919,    9],
#        [   2,    6,    0,    2,   31,    7,    0,   51,   11,  946]])

# %%
model.save('model_digits.h5')

# %%
import numpy as np
np.argmax(model.predict(x_test), axis=-1)
# Out:
# array([7, 2, 1, ..., 4, 5, 6])
